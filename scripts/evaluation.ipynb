# %%
import pandas as pd

# %%
csv_file = 'set1.csv'

# %%
df = pd.read_csv(csv_file, header = None)

# %%
df
# Out:
#                          0
# 0    frame_120_patch_0.jpg
# 1    frame_121_patch_0.jpg
# 2    frame_121_patch_1.jpg
# 3    frame_121_patch_2.jpg
# 4    frame_121_patch_3.jpg
# 5    frame_121_patch_4.jpg
# 6    frame_122_patch_0.jpg
# 7    frame_122_patch_1.jpg
# 8    frame_122_patch_2.jpg
# 9    frame_122_patch_3.jpg
# 10   frame_122_patch_4.jpg
# 11   frame_122_patch_5.jpg
# 12   frame_123_patch_0.jpg
# 13   frame_123_patch_1.jpg
# 14   frame_123_patch_2.jpg
# 15   frame_123_patch_3.jpg
# 16   frame_123_patch_4.jpg
# 17   frame_123_patch_5.jpg
# 18   frame_123_patch_6.jpg
# 19   frame_123_patch_7.jpg
# 20   frame_123_patch_8.jpg
# 21   frame_124_patch_0.jpg
# 22   frame_124_patch_1.jpg
# 23   frame_124_patch_2.jpg
# 24   frame_124_patch_3.jpg
# 25   frame_124_patch_4.jpg
# 26   frame_125_patch_0.jpg
# 27   frame_125_patch_1.jpg
# 28   frame_125_patch_2.jpg
# 29   frame_125_patch_3.jpg
# ..                     ...
# 729  frame_237_patch_9.jpg
# 730  frame_238_patch_0.jpg
# ...
