# %%
import pandas as pd

# %%
csv_file = 'set1_labeled.csv'

# %%
df = pd.read_csv(csv_file, names = ["image", "gt", "pred"])

# %%
lst = df.ix[:,1].tolist()
# Out:
# /home/xiuyuan/anaconda3/envs/fonduer/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
type(lst)
# Out:
# list

# %%
df["pred"] = 0

# %%
df
# Out:
#                      image  gt  pred
# 0    frame_120_patch_0.jpg   0     0
# 1    frame_121_patch_0.jpg   1     0
# 2    frame_121_patch_1.jpg   0     0
# 3    frame_121_patch_2.jpg   2     0
# 4    frame_121_patch_3.jpg   2     0
# 5    frame_121_patch_4.jpg   0     0
# 6    frame_122_patch_0.jpg   1     0
# 7    frame_122_patch_1.jpg   0     0
# 8    frame_122_patch_2.jpg   0     0
# 9    frame_122_patch_3.jpg   2     0
# 10   frame_122_patch_4.jpg   2     0
# 11   frame_122_patch_5.jpg   0     0
# 12   frame_123_patch_0.jpg   1     0
# 13   frame_123_patch_1.jpg   0     0
# 14   frame_123_patch_2.jpg   0     0
# 15   frame_123_patch_3.jpg   0     0
# 16   frame_123_patch_4.jpg   0     0
# 17   frame_123_patch_5.jpg   2     0
# 18   frame_123_patch_6.jpg   0     0
# 19   frame_123_patch_7.jpg   2     0
# 20   frame_123_patch_8.jpg   0     0
# 21   frame_124_patch_0.jpg   1     0
# 22   frame_124_patch_1.jpg   0     0
# 23   frame_124_patch_2.jpg   2     0
# ...

# %%
total = len(df)
truepred = 0
falsepred = 0
p = 0
r = 0
f1 = 0

# %%
for index, row in df.iterrows():
   if row["gt"]==row["pred"]:
    truepred+=1
   else:
    falsepred+=1

# %%
falsepred
# Out:
# 509
